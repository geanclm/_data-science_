# %% [markdown]
# ## DIO | Cognizant Cloud Data Engineer
# #### estudo iniciado em 1 de set. de 2021 17:59h

# %% [markdown]
# ## Fundamentos de ETL com Python

# %% [markdown]
# ###### Extrat: os dados são extraídos de diferentes fontes.
# ###### Transform: propagados para a área de preparação de dados, onde são transformados e limpos.
# ###### Load: carregados no warehouse.

# %% [markdown]
# ![cda804a712699845f08d8a3de2cffa29.jpg](attachment:cda804a712699845f08d8a3de2cffa29.jpg)

# %% [markdown]
# ## Ferramentas e pacotes para trabalhar com o Python

# %% [markdown]
# ![rqehp7jecwh1cp67vg8e.webp](attachment:rqehp7jecwh1cp67vg8e.webp)

# %% [markdown]
# ![simple-etl-in-python-35-with-bonobo-pyparis-2017-82-320.png](attachment:simple-etl-in-python-35-with-bonobo-pyparis-2017-82-320.png)

# %% [markdown]
# ![luigi.png](attachment:luigi.png)

# %% [markdown]
# ![images.png](attachment:images.png)

# %% [markdown]
# ![simple-etl-in-python-35-with-bonobo-pyparis-2017-82-320.png](attachment:simple-etl-in-python-35-with-bonobo-pyparis-2017-82-320.png)

# %% [markdown]
# ![petl.png](attachment:petl.png)

# %% [markdown]
# ![2560px-Pandas_logo.svg.png](attachment:2560px-Pandas_logo.svg.png)

# %% [markdown]
# ## Análise de dados com Python e Pandas
