# %% [markdown]
# # Title

# %%
# Análise de base de dados do Kaggle
# Bank Marketing

# %% [markdown]
# # Head

# %%
# by geanclm in 01/03/2022 at 19:15h

# %% [markdown]
# # Local files

# %%
# arquivos utilizados
# !dir
# Out:
#  O volume na unidade C ‚ Windows
#  O N£mero de S‚rie do Volume ‚ 2656-7D0D
#
#  Pasta de C:\Users\geanc\Downloads\DATA SCIENCE\FLAI\MBA\Data Analytics\Bank Marketing
#
# 04/03/2022  12:15    <DIR>          .
# 04/03/2022  12:15    <DIR>          ..
# 01/03/2022  19:08    <DIR>          .ipynb_checkpoints
# 01/03/2022  19:00         5.834.924 bank-additional-full__.csv
# 04/03/2022  12:15         1.766.937 bank-additional-full__.ods
# 01/03/2022  18:59             5.458 bank-additional-names.txt
# 04/03/2022  11:35            34.496 Kaggle_Bank_Marketing_csv.ipynb
#                4 arquivo(s)      7.641.815 bytes
#                3 pasta(s)   622.840.811.520 bytes dispon¡veis

# %% [markdown]
# # Import libs

# %%
import pandas as pd

# %% [markdown]
# # Metadata

# %%
# 01 - age (numeric) = idade
# 02 - job : type of job (categorical) = profissão
# 03 - marital : marital status (categorical) = estado civil
# 04 - education (categorical) = escolaridade
# 05 - default: has credit in default? (categorical) = inadimplente
# 06 - housing: has housing loan? (categorical) = crédito imobiliário
# 07 - loan: has personal loan? (categorical) = crédito pessoal
# 08 - contact: contact communication type (categorical) = contato
# 09 - month: last contact month of year (categorical) = último mês de contato
# 10 - day_of_week: last contact day of the week (categorical) = último dia da semana de contato
# 11 - duration: last contact duration, in seconds (numeric) = duração em segundos do último contato
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: (numeric) = número de dias desde o último contato
# 14 - previous: (numeric) = número de contatos feitos ao clientes antes da útima campanha
# 15 - poutcome: (categorical) = resultado da campanha
# 16 - emp.var.rate: (numeric) = tx de variação de emprego
# 17 - cons.price.idx: (numeric) = índice de preço ao consumidor (IPC)
# 18 - cons.conf.idx: (numeric) = índice de confiança do consumidor
# 19 - euribor3m: (numeric) = tx de 3 meses euribor
# 20 - nr.employed: (numeric) = número de empregados

# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes', 'no')

# %% [markdown]
# # Import data

# %%
# fonte: https://www.kaggle.com/henriqueyamahata/bank-marketing?select=bank-additional-names.txt
df = pd.read_csv('bank-additional-full__.csv', sep=';')

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df['age'].mean()
# Out:
# 40.02406040594348

# %%
# amostragem aleatória simples
df.sample(100)
# Out:
#        age            job  marital            education  default  housing  \
# 24568   35         admin.  married    university.degree       no       no
# 32739   30       services   single          high.school       no      yes
# 18624   53         admin.  married          high.school  unknown       no
# 30436   21        student   single              unknown       no      yes
# 2623    45       services   single  professional.course  unknown  unknown
# ...    ...            ...      ...                  ...      ...      ...
# 5934    28         admin.   single    university.degree       no       no
# 33736   38  self-employed  married             basic.9y       no       no
# 29939   40     technician   single  professional.course       no      yes
# 4841    40    blue-collar  married             basic.9y  unknown       no
# 37248   28         admin.  married    university.degree       no      yes
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 24568       no   cellular   nov         mon  ...         1    999         0
# 32739      yes   cellular   may         mon  ...         1    999         0
# 18624       no   cellular   jul         thu  ...         1    999         0
# 30436      yes   cellular   may         mon  ...         2    999         0
# 2623   unknown  telephone   may         tue  ...         2    999         0
# ...        ...        ...   ...         ...  ...       ...    ...       ...
# 5934        no  telephone   may         tue  ...         2    999         0
# 33736      yes  telephone   may         wed  ...         4    999         0
# 29939       no   cellular   apr         mon  ...         2    999         1
# 4841        no  telephone   may         wed  ...         2    999         0
# 37248       no   cellular   aug         fri  ...         1    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 24568  nonexistent         -0.1          93.200          -42.0      4.191
# 32739  nonexistent         -1.8          92.893          -46.2      1.299
# 18624  nonexistent          1.4          93.918          -42.7      4.968
# 30436  nonexistent         -1.8          92.893          -46.2      1.354
# 2623   nonexistent          1.1          93.994          -36.4      4.856
# ...            ...          ...             ...            ...        ...
# 5934   nonexistent          1.1          93.994          -36.4      4.857
# 33736  nonexistent         -1.8          92.893          -46.2      1.281
# 29939      failure         -1.8          93.075          -47.1      1.405
# 4841   nonexistent          1.1          93.994          -36.4      4.858
# 37248      failure         -2.9          92.201          -31.4      0.881
#
#        nr.employed    y
# 24568       5195.8   no
# 32739       5099.1   no
# 18624       5228.1   no
# 30436       5099.1  yes
# 2623        5191.0   no
# ...            ...  ...
# 5934        5191.0   no
# 33736       5099.1   no
# 29939       5099.1   no
# 4841        5191.0   no
# 37248       5076.2   no
#
# [100 rows x 21 columns]

# %%
# amostragem estratificada de 50 clients solteiros
df[df['marital']=='single'].sample(50)
# Out:
#        age            job marital            education  default housing loan  \
# 34909   24    blue-collar  single             basic.9y       no     yes   no
# 8586    45  self-employed  single          high.school       no      no   no
# 18230   35  self-employed  single    university.degree       no     yes   no
# 31829   34       services  single          high.school       no      no   no
# 6304    32         admin.  single          high.school       no     yes   no
# 37420   27     unemployed  single          high.school       no      no   no
# 21981   34     technician  single    university.degree       no     yes   no
# 11918   32         admin.  single    university.degree  unknown      no   no
# 7867    33     technician  single    university.degree       no     yes   no
# 15517   25     technician  single    university.degree       no      no   no
# 35250   24     technician  single  professional.course       no      no   no
# 39982   25        student  single          high.school       no     yes  yes
# 27929   28         admin.  single          high.school       no      no  yes
# 12756   31         admin.  single             basic.9y  unknown     yes   no
# 14656   27       services  single          high.school       no      no   no
# 17868   44        student  single              unknown  unknown      no  yes
# 32624   37     management  single             basic.9y       no      no   no
# 5399    28       services  single          high.school       no     yes  yes
# 13148   31         admin.  single          high.school       no      no   no
# 26911   31       services  single          high.school       no     yes   no
# 17790   57         admin.  single    university.degree       no      no   no
# 8242    36        student  single             basic.9y       no     yes   no
# 38323   25         admin.  single    university.degree       no     yes  yes
# 37017   25        student  single              unknown  unknown     yes   no
# 19244   32     technician  single  professional.course       no     yes   no
# 35035   32         admin.  single    university.degree       no     yes   no
# 27760   34     technician  single  professional.course       no     yes   no
# 21513   30     technician  single  professional.course       no      no   no
# 11927   31       services  single  professional.course       no     yes   no
# 11175   38     technician  single  professional.course       no      no   no
# 41130   31         admin.  single    university.degree       no     yes   no
# 39000   38     technician  single    university.degree       no     yes   no
# 17061   28       services  single          high.school       no      no   no
# 23443   31         admin.  single    university.degree       no     yes   no
# 30567   30     technician  single  professional.course       no      no   no
# 26151   36         admin.  single    university.degree       no     yes   no
# 26593   30    blue-collar  single          high.school       no      no   no
# 12748   29         admin.  single          high.school       no     yes   no
# 32976   32         admin.  single          high.school       no     yes   no
# 30304   21         admin.  single          high.school       no      no   no
# 19054   41     technician  single  professional.course       no     yes   no
# 29847   32    blue-collar  single             basic.6y       no      no   no
# 28766   24         admin.  single    university.degree       no     yes   no
# 27553   30         admin.  single          high.school       no      no  yes
# 36709   30     technician  single    university.degree       no     yes   no
# 39280   30     unemployed  single  professional.course       no     yes   no
# 40111   27         admin.  single    university.degree  unknown      no   no
# 33909   50    blue-collar  single  professional.course       no      no   no
# 17949   37         admin.  single          high.school       no     yes   no
# 7811    39         admin.  single    university.degree       no     yes  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 34909   cellular   may         fri  ...         4    999         0
# 8586   telephone   jun         wed  ...         1    999         0
# 18230   cellular   jul         wed  ...         2    999         0
# 31829   cellular   may         thu  ...         2    999         0
# 6304   telephone   may         tue  ...         4    999         0
# 37420   cellular   aug         wed  ...         1      4         3
# 21981   cellular   aug         wed  ...         1    999         0
# 11918  telephone   jun         fri  ...        15    999         0
# 7867   telephone   jun         mon  ...         1    999         0
# 15517   cellular   jul         fri  ...         2    999         0
# 35250   cellular   may         fri  ...         2    999         0
# 39982   cellular   jun         tue  ...         2      6         3
# 27929   cellular   mar         fri  ...         2    999         0
# 12756   cellular   jul         tue  ...         1    999         0
# 14656   cellular   jul         tue  ...         4    999         0
# 17868   cellular   jul         tue  ...         6    999         0
# 32624   cellular   may         mon  ...         1    999         0
# 5399   telephone   may         fri  ...         3    999         0
# 13148   cellular   jul         wed  ...         4    999         0
# 26911   cellular   nov         thu  ...         2    999         0
# 17790   cellular   jul         tue  ...         1    999         0
# 8242   telephone   jun         tue  ...         1    999         0
# 38323   cellular   oct         fri  ...         1    999         1
# 37017   cellular   jul         tue  ...         1    999         0
# 19244   cellular   aug         wed  ...         1    999         0
# 35035   cellular   may         fri  ...         8    999         1
# 27760   cellular   mar         fri  ...         1    999         0
# 21513   cellular   aug         tue  ...         2    999         0
# 11927  telephone   jun         fri  ...         2    999         0
# 11175  telephone   jun         thu  ...         4    999         0
# 41130   cellular   nov         thu  ...         1    999         0
# 39000   cellular   dec         mon  ...         2    999         0
# 17061   cellular   jul         fri  ...         2    999         0
# 23443   cellular   aug         wed  ...        17    999         0
# 30567   cellular   may         mon  ...         4    999         1
# 26151   cellular   nov         wed  ...         4    999         0
# 26593   cellular   nov         thu  ...         1    999         0
# 12748   cellular   jul         tue  ...         1    999         0
# 32976   cellular   may         mon  ...         2    999         0
# 30304   cellular   apr         thu  ...         2    999         0
# 19054   cellular   aug         tue  ...         1    999         0
# 29847   cellular   apr         mon  ...         4    999         0
# 28766   cellular   apr         thu  ...         1    999         0
# 27553   cellular   nov         fri  ...         2    999         1
# 36709   cellular   jun         fri  ...         2    999         0
# 39280   cellular   mar         mon  ...         1    999         0
# 40111   cellular   jul         mon  ...         6    999         0
# 33909   cellular   may         wed  ...         2    999         0
# 17949   cellular   jul         tue  ...         4    999         0
# 7811   telephone   jun         mon  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 34909  nonexistent         -1.8          92.893          -46.2      1.250
# 8586   nonexistent          1.4          94.465          -41.8      4.864
# 18230  nonexistent          1.4          93.918          -42.7      4.963
# 31829  nonexistent         -1.8          92.893          -46.2      1.327
# 6304   nonexistent          1.1          93.994          -36.4      4.857
# 37420      success         -2.9          92.201          -31.4      0.879
# 21981  nonexistent          1.4          93.444          -36.1      4.964
# 11918  nonexistent          1.4          94.465          -41.8      4.959
# 7867   nonexistent          1.4          94.465          -41.8      4.865
# 15517  nonexistent          1.4          93.918          -42.7      4.957
# 35250  nonexistent         -1.8          92.893          -46.2      1.250
# 39982      success         -1.7          94.055          -39.8      0.761
# 27929  nonexistent         -1.8          92.843          -50.0      1.531
# 12756  nonexistent          1.4          93.918          -42.7      4.962
# 14656  nonexistent          1.4          93.918          -42.7      4.961
# 17868  nonexistent          1.4          93.918          -42.7      4.961
# 32624  nonexistent         -1.8          92.893          -46.2      1.299
# 5399   nonexistent          1.1          93.994          -36.4      4.857
# 13148  nonexistent          1.4          93.918          -42.7      4.962
# 26911  nonexistent         -0.1          93.200          -42.0      4.076
# 17790  nonexistent          1.4          93.918          -42.7      4.961
# 8242   nonexistent          1.4          94.465          -41.8      4.864
# 38323      failure         -3.4          92.431          -26.9      0.739
# 37017  nonexistent         -2.9          92.469          -33.6      1.044
# 19244  nonexistent          1.4          93.444          -36.1      4.967
# 35035      failure         -1.8          92.893          -46.2      1.250
# 27760  nonexistent         -1.8          92.843          -50.0      1.726
# 21513  nonexistent          1.4          93.444          -36.1      4.963
# 11927  nonexistent          1.4          94.465          -41.8      4.959
# 11175  nonexistent          1.4          94.465          -41.8      4.961
# 41130  nonexistent         -1.1          94.767          -50.8      1.041
# 39000  nonexistent         -3.0          92.713          -33.0      0.717
# 17061  nonexistent          1.4          93.918          -42.7      4.962
# 23443  nonexistent          1.4          93.444          -36.1      4.964
# 30567      failure         -1.8          92.893          -46.2      1.354
# 26151  nonexistent         -0.1          93.200          -42.0      4.120
# 26593  nonexistent         -0.1          93.200          -42.0      4.076
# 12748  nonexistent          1.4          93.918          -42.7      4.962
# 32976  nonexistent         -1.8          92.893          -46.2      1.299
# 30304  nonexistent         -1.8          93.075          -47.1      1.365
# 19054  nonexistent          1.4          93.444          -36.1      4.968
# 29847  nonexistent         -1.8          93.075          -47.1      1.405
# 28766  nonexistent         -1.8          93.075          -47.1      1.410
# 27553      failure         -0.1          93.200          -42.0      4.021
# 36709  nonexistent         -2.9          92.963          -40.8      1.268
# 39280  nonexistent         -1.8          93.369          -34.8      0.646
# 40111  nonexistent         -1.7          94.215          -40.3      0.827
# 33909  nonexistent         -1.8          92.893          -46.2      1.281
# 17949  nonexistent          1.4          93.918          -42.7      4.961
# 7811   nonexistent          1.4          94.465          -41.8      4.865
#
#        nr.employed    y
# 34909       5099.1   no
# 8586        5228.1   no
# 18230       5228.1   no
# 31829       5099.1  yes
# 6304        5191.0   no
# 37420       5076.2   no
# 21981       5228.1   no
# 11918       5228.1   no
# 7867        5228.1   no
# 15517       5228.1   no
# 35250       5099.1   no
# 39982       4991.6  yes
# 27929       5099.1   no
# 12756       5228.1   no
# 14656       5228.1   no
# 17868       5228.1   no
# 32624       5099.1   no
# 5399        5191.0   no
# 13148       5228.1   no
# 26911       5195.8   no
# 17790       5228.1   no
# 8242        5228.1   no
# 38323       5017.5  yes
# 37017       5076.2  yes
# 19244       5228.1   no
# 35035       5099.1   no
# 27760       5099.1  yes
# 21513       5228.1   no
# 11927       5228.1   no
# 11175       5228.1   no
# 41130       4963.6  yes
# 39000       5023.5  yes
# 17061       5228.1   no
# 23443       5228.1   no
# 30567       5099.1   no
# 26151       5195.8   no
# 26593       5195.8   no
# 12748       5228.1   no
# 32976       5099.1   no
# 30304       5099.1   no
# 19054       5228.1   no
# 29847       5099.1   no
# 28766       5099.1  yes
# 27553       5195.8   no
# 36709       5076.2  yes
# 39280       5008.7   no
# 40111       4991.6   no
# 33909       5099.1   no
# 17949       5228.1   no
# 7811        5228.1   no
#
# [50 rows x 21 columns]

# %%
# amostragem estratificada de 50 clientes casados
df[df['marital']=='married'].sample(50)
# Out:
#        age            job  marital            education  default housing loan  \
# 28366   52         admin.  married          high.school       no      no   no
# 32849   39    blue-collar  married             basic.4y       no      no   no
# 12663   51    blue-collar  married              unknown  unknown     yes   no
# 21165   35     technician  married  professional.course       no     yes   no
# 17610   30         admin.  married              unknown       no      no   no
# 10212   48         admin.  married          high.school  unknown      no   no
# 13005   28       services  married          high.school       no      no   no
# 2475    51    blue-collar  married             basic.4y  unknown      no   no
# 36680   55      housemaid  married              unknown       no      no   no
# 25957   32   entrepreneur  married    university.degree       no     yes  yes
# 39407   46     technician  married  professional.course       no      no  yes
# 33820   58        retired  married             basic.4y  unknown     yes   no
# 6417    35       services  married          high.school       no      no   no
# 23410   44         admin.  married             basic.9y  unknown      no   no
# 26449   34     management  married    university.degree       no      no   no
# 37326   60        retired  married          high.school       no      no   no
# 17883   57      housemaid  married          high.school  unknown      no   no
# 18183   36         admin.  married          high.school       no     yes   no
# 31922   40         admin.  married             basic.9y       no     yes  yes
# 31104   55    blue-collar  married             basic.9y       no     yes   no
# 38184   82        retired  married    university.degree       no     yes   no
# 4615    58        retired  married    university.degree       no      no   no
# 1130    39     management  married    university.degree       no     yes   no
# 30717   39    blue-collar  married             basic.9y       no      no   no
# 32475   46       services  married             basic.4y       no     yes   no
# 4890    51   entrepreneur  married             basic.4y  unknown     yes   no
# 37033   31     technician  married    university.degree       no      no   no
# 3160    53        unknown  married          high.school  unknown      no   no
# 35489   30         admin.  married             basic.9y       no     yes  yes
# 7466    41    blue-collar  married             basic.4y       no     yes   no
# 6222    36       services  married          high.school  unknown      no   no
# 16790   54       services  married          high.school  unknown      no   no
# 24673   37     management  married          high.school       no     yes   no
# 35156   49  self-employed  married          high.school       no      no   no
# 28121   42     management  married              unknown       no     yes   no
# 38544   31         admin.  married          high.school       no     yes   no
# 13638   40     technician  married             basic.9y       no     yes   no
# 10593   34     management  married    university.degree       no     yes   no
# 7284    54         admin.  married    university.degree  unknown      no  yes
# 10914   31    blue-collar  married             basic.9y       no      no   no
# 21883   53    blue-collar  married             basic.4y       no     yes   no
# 20653   54       services  married             basic.4y       no     yes  yes
# 22281   52         admin.  married              unknown       no     yes   no
# 11516   36         admin.  married    university.degree       no     yes  yes
# 38171   51     technician  married  professional.course       no     yes   no
# 37168   37         admin.  married    university.degree       no      no   no
# 25832   30       services  married  professional.course       no     yes   no
# 30583   50  self-employed  married          high.school       no     yes   no
# 7083    28    blue-collar  married             basic.4y       no      no   no
# 21247   50    blue-collar  married             basic.9y       no     yes  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 28366   cellular   apr         thu  ...         2    999         0
# 32849   cellular   may         mon  ...         2    999         0
# 12663   cellular   jul         mon  ...         2    999         0
# 21165   cellular   aug         mon  ...         2    999         0
# 17610   cellular   jul         mon  ...         3    999         0
# 10212  telephone   jun         mon  ...         2    999         0
# 13005   cellular   jul         tue  ...         1    999         0
# 2475   telephone   may         tue  ...         2    999         0
# 36680   cellular   jun         fri  ...         1    999         1
# 25957   cellular   nov         wed  ...         1    999         0
# 39407   cellular   apr         tue  ...         1      5         2
# 33820   cellular   may         wed  ...         1    999         1
# 6417   telephone   may         wed  ...         2    999         0
# 23410   cellular   aug         wed  ...        17    999         0
# 26449  telephone   nov         thu  ...         1    999         0
# 37326   cellular   aug         tue  ...         1      4         1
# 17883  telephone   jul         tue  ...         1    999         0
# 18183   cellular   jul         wed  ...        13    999         0
# 31922   cellular   may         thu  ...         2     10         1
# 31104   cellular   may         wed  ...         1    999         0
# 38184   cellular   oct         tue  ...         1    999         0
# 4615   telephone   may         tue  ...         2    999         0
# 1130   telephone   may         wed  ...         3    999         0
# 30717   cellular   may         tue  ...         1    999         0
# 32475   cellular   may         fri  ...         3    999         1
# 4890   telephone   may         wed  ...         3    999         0
# 37033   cellular   jul         tue  ...         1    999         0
# 3160   telephone   may         thu  ...         1    999         0
# 35489   cellular   may         mon  ...         1    999         1
# 7466   telephone   may         fri  ...         2    999         0
# 6222   telephone   may         tue  ...         3    999         0
# 16790  telephone   jul         thu  ...         1    999         0
# 24673  telephone   nov         mon  ...         2    999         1
# 35156   cellular   may         fri  ...         3    999         0
# 28121   cellular   apr         mon  ...         2    999         1
# 38544   cellular   oct         thu  ...         2    999         1
# 13638   cellular   jul         thu  ...         1    999         0
# 10593  telephone   jun         tue  ...         2    999         0
# 7284   telephone   may         thu  ...         2    999         0
# 10914  telephone   jun         wed  ...         1    999         0
# 21883   cellular   aug         wed  ...         2    999         0
# 20653   cellular   aug         wed  ...         1    999         0
# 22281   cellular   aug         thu  ...         2    999         0
# 11516  telephone   jun         fri  ...         2    999         0
# 38171   cellular   oct         thu  ...         6      6         3
# 37168   cellular   aug         thu  ...         1    999         0
# 25832   cellular   nov         wed  ...         2    999         0
# 30583   cellular   may         mon  ...         3    999         0
# 7083   telephone   may         thu  ...         3    999         0
# 21247   cellular   aug         mon  ...         3    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 28366  nonexistent         -1.8          93.075          -47.1      1.435
# 32849  nonexistent         -1.8          92.893          -46.2      1.299
# 12663  nonexistent          1.4          93.918          -42.7      4.960
# 21165  nonexistent          1.4          93.444          -36.1      4.963
# 17610  nonexistent          1.4          93.918          -42.7      4.962
# 10212  nonexistent          1.4          94.465          -41.8      4.960
# 13005  nonexistent          1.4          93.918          -42.7      4.962
# 2475   nonexistent          1.1          93.994          -36.4      4.856
# 36680      failure         -2.9          92.963          -40.8      1.268
# 25957  nonexistent         -0.1          93.200          -42.0      4.120
# 39407      success         -1.8          93.749          -34.6      0.638
# 33820      failure         -1.8          92.893          -46.2      1.281
# 6417   nonexistent          1.1          93.994          -36.4      4.857
# 23410  nonexistent          1.4          93.444          -36.1      4.964
# 26449  nonexistent         -0.1          93.200          -42.0      4.076
# 37326      success         -2.9          92.201          -31.4      0.883
# 17883  nonexistent          1.4          93.918          -42.7      4.961
# 18183  nonexistent          1.4          93.918          -42.7      4.963
# 31922      success         -1.8          92.893          -46.2      1.327
# 31104  nonexistent         -1.8          92.893          -46.2      1.334
# 38184  nonexistent         -3.4          92.431          -26.9      0.744
# 4615   nonexistent          1.1          93.994          -36.4      4.856
# 1130   nonexistent          1.1          93.994          -36.4      4.856
# 30717  nonexistent         -1.8          92.893          -46.2      1.344
# 32475      failure         -1.8          92.893          -46.2      1.313
# 4890   nonexistent          1.1          93.994          -36.4      4.858
# 37033  nonexistent         -2.9          92.469          -33.6      1.044
# 3160   nonexistent          1.1          93.994          -36.4      4.860
# 35489      failure         -1.8          92.893          -46.2      1.244
# 7466   nonexistent          1.1          93.994          -36.4      4.864
# 6222   nonexistent          1.1          93.994          -36.4      4.857
# 16790  nonexistent          1.4          93.918          -42.7      4.962
# 24673      failure         -0.1          93.200          -42.0      4.191
# 35156  nonexistent         -1.8          92.893          -46.2      1.250
# 28121      failure         -1.8          93.075          -47.1      1.466
# 38544      failure         -3.4          92.431          -26.9      0.722
# 13638  nonexistent          1.4          93.918          -42.7      4.963
# 10593  nonexistent          1.4          94.465          -41.8      4.961
# 7284   nonexistent          1.1          93.994          -36.4      4.860
# 10914  nonexistent          1.4          94.465          -41.8      4.962
# 21883  nonexistent          1.4          93.444          -36.1      4.964
# 20653  nonexistent          1.4          93.444          -36.1      4.965
# 22281  nonexistent          1.4          93.444          -36.1      4.963
# 11516  nonexistent          1.4          94.465          -41.8      4.959
# 38171      failure         -3.4          92.431          -26.9      0.754
# 37168  nonexistent         -2.9          92.201          -31.4      0.883
# 25832  nonexistent         -0.1          93.200          -42.0      4.120
# 30583  nonexistent         -1.8          92.893          -46.2      1.354
# 7083   nonexistent          1.1          93.994          -36.4      4.860
# 21247  nonexistent          1.4          93.444          -36.1      4.963
#
#        nr.employed    y
# 28366       5099.1   no
# 32849       5099.1   no
# 12663       5228.1   no
# 21165       5228.1   no
# 17610       5228.1   no
# 10212       5228.1   no
# 13005       5228.1   no
# 2475        5191.0   no
# 36680       5076.2   no
# 25957       5195.8   no
# 39407       5008.7  yes
# 33820       5099.1   no
# 6417        5191.0   no
# 23410       5228.1   no
# 26449       5195.8   no
# 37326       5076.2   no
# 17883       5228.1   no
# 18183       5228.1   no
# 31922       5099.1   no
# 31104       5099.1   no
# 38184       5017.5  yes
# 4615        5191.0   no
# 1130        5191.0   no
# 30717       5099.1   no
# 32475       5099.1   no
# 4890        5191.0   no
# 37033       5076.2   no
# 3160        5191.0   no
# 35489       5099.1   no
# 7466        5191.0   no
# 6222        5191.0   no
# 16790       5228.1   no
# 24673       5195.8   no
# 35156       5099.1  yes
# 28121       5099.1   no
# 38544       5017.5   no
# 13638       5228.1   no
# 10593       5228.1   no
# 7284        5191.0   no
# 10914       5228.1   no
# 21883       5228.1   no
# 20653       5228.1   no
# 22281       5228.1   no
# 11516       5228.1   no
# 38171       5017.5   no
# 37168       5076.2   no
# 25832       5195.8  yes
# 30583       5099.1   no
# 7083        5191.0   no
# 21247       5228.1   no
#
# [50 rows x 21 columns]
